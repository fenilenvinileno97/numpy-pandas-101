# %%
import pandas as pd

# %%
headers = [
    'Work year',
    'Experience level',
    'Employment type',
    'Job title',
    'Salary',
    'Salary currency',
    'Salary in usd',
    'Employee residence',
    'Remote ratio',
    'Company location',
    'Company size']

# %%
pd.read_csv('./imgs/ds_salaries.csv', sep=',', header=0, names=headers).head(5)
# Out:
#    Work year Experience level Employment type                   Job title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    Salary Salary currency  Salary in usd Employee residence  Remote ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   Company location Company size
# 0               DE            L
# ...

# %%
pd.read_csv('./imgs/ds_salaries.csv', sep=',', names=headers, header=3).head(10)
# Out:
#     Work year Experience level Employment type                  Job title  \
# 3        2020               MI              FT       Product Data Analyst
# 4        2020               SE              FT  Machine Learning Engineer
# 5        2020               EN              FT               Data Analyst
# 6        2020               SE              FT        Lead Data Scientist
# 7        2020               MI              FT             Data Scientist
# 8        2020               MI              FT      Business Data Analyst
# 9        2020               SE              FT         Lead Data Engineer
# 10       2020               EN              FT             Data Scientist
# 11       2020               MI              FT             Data Scientist
# 12       2020               EN              FT             Data Scientist
#
#       Salary Salary currency  Salary in usd Employee residence  Remote ratio  \
# ...

# %% [markdown]
# ##### `Reading JSON files`

# %%
json_file = pd.read_json('./imgs/hp_char.json')
json_file.head(10)
# Out:
#                    Name                                               Link  \
# 0           Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1         Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2         Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3      Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4  Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# 5             Abernathy    https://www.hp-lexicon.org/character/abernathy/
# 6     Abraham Peasegood  https://www.hp-lexicon.org/character/abraham-p...
# 7        Abraham Potter  https://www.hp-lexicon.org/character/potter-fa...
# 8        Abraxas Malfoy  https://www.hp-lexicon.org/character/malfoy-fa...
# 9     Achilles Tolliver  https://www.hp-lexicon.org/character/achilles-...
#
#                                                Descr  Gender Species/Race  \
# ...
