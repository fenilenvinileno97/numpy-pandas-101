# %%
import pandas as pd

# %%
df_salaries = pd.read_csv('./imgs/ds_salaries.csv', sep=',', header=0)

# %%
df_salaries.loc[:]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df_salaries.loc[0:10]
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# 5            5       2020               EN              FT
# 6            6       2020               SE              FT
# 7            7       2020               MI              FT
# 8            8       2020               MI              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 0               Data Scientist     70000             EUR          79833
# 1   Machine Learning Scientist    260000             USD         260000
# ...

# %%
df_salaries.loc[0:10, ['job_title', 'salary']]
# Out:
#                      job_title    salary
# 0               Data Scientist     70000
# 1   Machine Learning Scientist    260000
# 2            Big Data Engineer     85000
# 3         Product Data Analyst     20000
# 4    Machine Learning Engineer    150000
# 5                 Data Analyst     72000
# 6          Lead Data Scientist    190000
# 7               Data Scientist  11000000
# 8        Business Data Analyst    135000
# 9           Lead Data Engineer    125000
# 10              Data Scientist     45000

# %%
df_salaries.loc[:, ['salary_in_usd']] * (4447.50/12)
# Out:
#      salary_in_usd
# 0     2.958811e+07
# 1     9.636250e+07
# 2     4.040702e+07
# 3     7.412500e+06
# 4     5.559375e+07
# ..             ...
# 602   5.707625e+07
# 603   4.669875e+07
# 604   4.781062e+07
# 605   5.559375e+07
# 606   7.412500e+07
#
# [607 rows x 1 columns]

# %%
condition = df_salaries.loc[:, ['employment_type']] == 'HT'
condition
# Out:
#      employment_type
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 602            False
# 603            False
# 604            False
# 605            False
# 606            False
#
# [607 rows x 1 columns]

# %% [markdown]
# #### `.iloc()`

# %%
df_salaries.iloc[:]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df_salaries.iloc[:4, 0:6]
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
#
#                     job_title  salary
# 0              Data Scientist   70000
# 1  Machine Learning Scientist  260000
# 2           Big Data Engineer   85000
# 3        Product Data Analyst   20000

# %%
df_salaries.iloc[1,4]
# Out:
# 'Machine Learning Scientist'

# %%
df_salaries[(df_salaries['job_title'] == 'Data Scientist') & (df_salaries['salary_in_usd'] > 50000)]
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0             0       2020               MI              FT  Data Scientist
# 10           10       2020               EN              FT  Data Scientist
# 32           32       2020               SE              FT  Data Scientist
# 46           46       2020               MI              FT  Data Scientist
# 48           48       2020               MI              FT  Data Scientist
# ..          ...        ...              ...             ...             ...
# 592         592       2022               SE              FT  Data Scientist
# 593         593       2022               SE              FT  Data Scientist
# 596         596       2022               SE              FT  Data Scientist
# 598         598       2022               MI              FT  Data Scientist
# 599         599       2022               MI              FT  Data Scientist
#
# ...
